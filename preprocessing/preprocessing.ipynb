# %% [markdown]
# # Data Preprocessing #

# %% [markdown]
# ### Loading Data and Libraries ###

# %%
import pandas as pd 
import re
import numpy as np
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer 
from nltk.tokenize import word_tokenize

# %%
# read csv
tweets_df = pd.read_csv('all_tweets.csv')
# Out:
# <ipython-input-2-1197a4774794>:2: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   tweets_df = pd.read_csv('all_tweets.csv')

# %%
# drop the rows having NaN values
tweets_df = tweets_df.dropna()
 
# reset the indices
tweets_df = tweets_df.reset_index(drop = True)

# %% [markdown]
# ### Cleaning Text ###

# %%
# remove mentions, hashtags, RT, and urls
def clean_text (text):
    text = re.sub(r'@[A-Za-z0-9_]+','', text)
    text = re.sub(r'#', '', text)
    text = re.sub(r'RT[\s]+', '', text)
    text = re.sub(r'https?:\/\/\S+', '', text)
    text = re.sub(r'\d+', '',text)
    return text

# %%
# make new column for cleaned tweets
tweets_df['cleaned_text'] = tweets_df['Text'].apply(clean_text)
tweets_df.head()
    
    
# lowercase
tweets_df['cleaned_text'] = tweets_df['cleaned_text'].apply(lambda x: ' ' .join(x.lower() for x in x.split()))

tweets_df.head()
# Out:
#   Unnamed: 0                   Datetime      Tweet Id  \
# 0          0  2015-12-30 19:16:32+00:00  6.822791e+17
# 1          1  2015-12-30 17:11:12+00:00  6.822476e+17
# 2          2  2015-12-30 16:13:04+00:00  6.822329e+17
# 3          3  2015-12-30 15:25:33+00:00  6.822210e+17
# 4          4  2015-12-30 04:59:08+00:00  6.820633e+17
#
#                                                 Text         Username  \
# 0  @Daily_Star they better keep a close eye on th...      carisbrook5
# 1  Calling customer service lines gives me #diarr...  ktandthekittens
# 2  5 Ways to Relieve Stress in 2016 https://t.co/...    ThriveStreams
# 3  Sweet story. #anxiety #depression #coping #men...         ynniv129
# 4  5 Different Types of Motivation https://t.co/x...        workttech
#
#                                         cleaned_text
# 0  they better keep a close eye on this kid, so t...
# 1  calling customer service lines gives me diarrh...
# 2  ways to relieve stress in via our blog mentalh...
# 3  sweet story. anxiety depression coping mentalh...
# 4  different types of motivation motivation menta...

# %%
# remove punctuation
tweets_df['cleaned_text'] = tweets_df['cleaned_text'].str.replace(r'[^\w\s]+', '')

tweets_df.head()
# Out:
# <ipython-input-6-94dbd92536b6>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   tweets_df['cleaned_text'] = tweets_df['cleaned_text'].str.replace(r'[^\w\s]+', '')
#   Unnamed: 0                   Datetime      Tweet Id  \
# 0          0  2015-12-30 19:16:32+00:00  6.822791e+17
# 1          1  2015-12-30 17:11:12+00:00  6.822476e+17
# 2          2  2015-12-30 16:13:04+00:00  6.822329e+17
# 3          3  2015-12-30 15:25:33+00:00  6.822210e+17
# 4          4  2015-12-30 04:59:08+00:00  6.820633e+17
#
#                                                 Text         Username  \
# 0  @Daily_Star they better keep a close eye on th...      carisbrook5
# 1  Calling customer service lines gives me #diarr...  ktandthekittens
# 2  5 Ways to Relieve Stress in 2016 https://t.co/...    ThriveStreams
# 3  Sweet story. #anxiety #depression #coping #men...         ynniv129
# 4  5 Different Types of Motivation https://t.co/x...        workttech
#
#                                         cleaned_text
# 0  they better keep a close eye on this kid so th...
# 1  calling customer service lines gives me diarrh...
# 2  ways to relieve stress in via our blog mentalh...
# 3  sweet story anxiety depression coping mentalhe...
# 4  different types of motivation motivation menta...

# %%
# extend stop list
stp_wrds = ['youd','lyn','ive','id','shed','hed','itd','hows','amp','ra','thats','can','could',\
            'should','would','rt','cant','dont','shouldve','im','u','b','doesnt','havent',\
            'hadnt','isnt','shouldnt','wasnt','werent','wont','wouldnt','youll','youre','ur','ull']
stop_words = stopwords.words('english')
stop_words.extend(stp_wrds)

tweets_df['cleaned_text'] = tweets_df.apply(lambda row: nltk.word_tokenize(row['cleaned_text']), axis=1)

# remove stop words
tweets_df['cleaned_text'] = tweets_df['cleaned_text'].apply(lambda words: [word for word in words if word not in stop_words])
    
tweets_df['cleaned_text'] = tweets_df['cleaned_text'].str.join(" ")

tweets_df.head()
# Out:
#   Unnamed: 0                   Datetime      Tweet Id  \
# 0          0  2015-12-30 19:16:32+00:00  6.822791e+17
# 1          1  2015-12-30 17:11:12+00:00  6.822476e+17
# 2          2  2015-12-30 16:13:04+00:00  6.822329e+17
# 3          3  2015-12-30 15:25:33+00:00  6.822210e+17
# 4          4  2015-12-30 04:59:08+00:00  6.820633e+17
#
#                                                 Text         Username  \
# 0  @Daily_Star they better keep a close eye on th...      carisbrook5
# 1  Calling customer service lines gives me #diarr...  ktandthekittens
# 2  5 Ways to Relieve Stress in 2016 https://t.co/...    ThriveStreams
# 3  Sweet story. #anxiety #depression #coping #men...         ynniv129
# 4  5 Different Types of Motivation https://t.co/x...        workttech
#
#                                         cleaned_text
# 0  better keep close eye kid commit suicide depre...
# 1  calling customer service lines gives diarrhea ...
# 2  ways relieve stress via blog mentalhealth newy...
# 3  sweet story anxiety depression coping mentalhe...
# 4  different types motivation motivation mentalhe...

# %%
# lemmatize
tokenizer = nltk.WhitespaceTokenizer()
lemmatizer = nltk.WordNetLemmatizer()

def lemmatize_text(text):
    return [lemmatizer.lemmatize(w) for w in tokenizer.tokenize(text)]

tweets_df['cleaned_text'] = tweets_df['cleaned_text'].apply(lemmatize_text)

# %%
# rejoin tokens
tweets_df['cleaned_text'] = tweets_df['cleaned_text'].str.join(" ")

tweets_df.head()
# Out:
#   Unnamed: 0                   Datetime      Tweet Id  \
# 0          0  2015-12-30 19:16:32+00:00  6.822791e+17
# 1          1  2015-12-30 17:11:12+00:00  6.822476e+17
# 2          2  2015-12-30 16:13:04+00:00  6.822329e+17
# 3          3  2015-12-30 15:25:33+00:00  6.822210e+17
# 4          4  2015-12-30 04:59:08+00:00  6.820633e+17
#
#                                                 Text         Username  \
# 0  @Daily_Star they better keep a close eye on th...      carisbrook5
# 1  Calling customer service lines gives me #diarr...  ktandthekittens
# 2  5 Ways to Relieve Stress in 2016 https://t.co/...    ThriveStreams
# 3  Sweet story. #anxiety #depression #coping #men...         ynniv129
# 4  5 Different Types of Motivation https://t.co/x...        workttech
#
#                                         cleaned_text
# 0  better keep close eye kid commit suicide depre...
# 1  calling customer service line give diarrhea tm...
# 2  way relieve stress via blog mentalhealth newye...
# 3  sweet story anxiety depression coping mentalhe...
# 4  different type motivation motivation mentalhealth

# %%
# remove words with less than 2 characters
tweets_df['cleaned_text']= tweets_df['cleaned_text'].apply(lambda x: [word for word in x.split() if len(word) > 2])
tweets_df['cleaned_text'] = tweets_df['cleaned_text'].str.join(" ")
tweets_df.head()
# Out:
#   Unnamed: 0                   Datetime      Tweet Id  \
# 0          0  2015-12-30 19:16:32+00:00  6.822791e+17
# 1          1  2015-12-30 17:11:12+00:00  6.822476e+17
# 2          2  2015-12-30 16:13:04+00:00  6.822329e+17
# 3          3  2015-12-30 15:25:33+00:00  6.822210e+17
# 4          4  2015-12-30 04:59:08+00:00  6.820633e+17
#
#                                                 Text         Username  \
# 0  @Daily_Star they better keep a close eye on th...      carisbrook5
# 1  Calling customer service lines gives me #diarr...  ktandthekittens
# 2  5 Ways to Relieve Stress in 2016 https://t.co/...    ThriveStreams
# 3  Sweet story. #anxiety #depression #coping #men...         ynniv129
# 4  5 Different Types of Motivation https://t.co/x...        workttech
#
#                                         cleaned_text
# 0  better keep close eye kid commit suicide depre...
# 1  calling customer service line give diarrhea tm...
# 2  way relieve stress via blog mentalhealth newye...
# 3  sweet story anxiety depression coping mentalhe...
# 4  different type motivation motivation mentalhealth

# %%
# remove leftover issues
tweets_df['cleaned_text'] = tweets_df['cleaned_text'].str.replace(r'_', '')

tweets_df.head()
# Out:
#   Unnamed: 0                   Datetime      Tweet Id  \
# 0          0  2015-12-30 19:16:32+00:00  6.822791e+17
# 1          1  2015-12-30 17:11:12+00:00  6.822476e+17
# 2          2  2015-12-30 16:13:04+00:00  6.822329e+17
# 3          3  2015-12-30 15:25:33+00:00  6.822210e+17
# 4          4  2015-12-30 04:59:08+00:00  6.820633e+17
#
#                                                 Text         Username  \
# 0  @Daily_Star they better keep a close eye on th...      carisbrook5
# 1  Calling customer service lines gives me #diarr...  ktandthekittens
# 2  5 Ways to Relieve Stress in 2016 https://t.co/...    ThriveStreams
# 3  Sweet story. #anxiety #depression #coping #men...         ynniv129
# 4  5 Different Types of Motivation https://t.co/x...        workttech
#
#                                         cleaned_text
# 0  better keep close eye kid commit suicide depre...
# 1  calling customer service line give diarrhea tm...
# 2  way relieve stress via blog mentalhealth newye...
# 3  sweet story anxiety depression coping mentalhe...
# 4  different type motivation motivation mentalhealth

# %% [markdown]
# ### Adjusting Datetime Column ###

# %%
# convert to datetime
tweets_df['Date'] = pd.to_datetime(tweets_df['Datetime'])
tweets_df.info()

# drop old date column
tweets_df = tweets_df.drop('Datetime', axis = 1)

tweets_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 386930 entries, 0 to 386929
# Data columns (total 7 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0    386930 non-null  object
#  1   Datetime      386930 non-null  object
#  2   Tweet Id      386930 non-null  float64
#  3   Text          386930 non-null  object
#  4   Username      386930 non-null  object
#  5   cleaned_text  386930 non-null  object
#  6   Date          386930 non-null  datetime64[ns, UTC]
# dtypes: datetime64[ns, UTC](1), float64(1), object(5)
# memory usage: 20.7+ MB
#   Unnamed: 0      Tweet Id                                               Text  \
# 0          0  6.822791e+17  @Daily_Star they better keep a close eye on th...
# 1          1  6.822476e+17  Calling customer service lines gives me #diarr...
# 2          2  6.822329e+17  5 Ways to Relieve Stress in 2016 https://t.co/...
# 3          3  6.822210e+17  Sweet story. #anxiety #depression #coping #men...
# 4          4  6.820633e+17  5 Different Types of Motivation https://t.co/x...
#
#           Username                                       cleaned_text  \
# 0      carisbrook5  better keep close eye kid commit suicide depre...
# 1  ktandthekittens  calling customer service line give diarrhea tm...
# 2    ThriveStreams  way relieve stress via blog mentalhealth newye...
# 3         ynniv129  sweet story anxiety depression coping mentalhe...
# 4        workttech  different type motivation motivation mentalhealth
#
#                        Date
# 0 2015-12-30 19:16:32+00:00
# 1 2015-12-30 17:11:12+00:00
# 2 2015-12-30 16:13:04+00:00
# 3 2015-12-30 15:25:33+00:00
# 4 2015-12-30 04:59:08+00:00

# %%
tweets_df['year'] = pd.DatetimeIndex(tweets_df['Date']).year
tweets_df['month'] = pd.DatetimeIndex(tweets_df['Date']).month
tweets_df.head()
# Out:
#   Unnamed: 0      Tweet Id                                               Text  \
# 0          0  6.822791e+17  @Daily_Star they better keep a close eye on th...
# 1          1  6.822476e+17  Calling customer service lines gives me #diarr...
# 2          2  6.822329e+17  5 Ways to Relieve Stress in 2016 https://t.co/...
# 3          3  6.822210e+17  Sweet story. #anxiety #depression #coping #men...
# 4          4  6.820633e+17  5 Different Types of Motivation https://t.co/x...
#
#           Username                                       cleaned_text  \
# 0      carisbrook5  better keep close eye kid commit suicide depre...
# 1  ktandthekittens  calling customer service line give diarrhea tm...
# 2    ThriveStreams  way relieve stress via blog mentalhealth newye...
# 3         ynniv129  sweet story anxiety depression coping mentalhe...
# 4        workttech  different type motivation motivation mentalhealth
#
#                        Date  year  month
# 0 2015-12-30 19:16:32+00:00  2015     12
# 1 2015-12-30 17:11:12+00:00  2015     12
# 2 2015-12-30 16:13:04+00:00  2015     12
# 3 2015-12-30 15:25:33+00:00  2015     12
# 4 2015-12-30 04:59:08+00:00  2015     12

# %%
# save to csv
tweets_df.to_csv('clean_tweets.csv')
